# %%
import pandas as pd

# %%
df = pd.read_csv('/Users/davidlloyd/Documents/Networks/2017_MSSP_Less_Cols.csv',encoding = "ISO-8859-1")

# %%
#Before with dupes
df
# Out:
#       ACO_Num                                    ACO_Name ACO_Service_Area  \
# 0      A92107                           Central Maine ACO               ME
# 1      A38665                                       CCACO           NJ, NY
# 2      A06665                              JFK Health ACO               NJ
# 3      A17182        AAMC Collaborative Care Network, LLC               MD
# 4      A17182        AAMC Collaborative Care Network, LLC               MD
# 5      A17182        AAMC Collaborative Care Network, LLC               MD
# 6      A17182        AAMC Collaborative Care Network, LLC               MD
# 7      A17182        AAMC Collaborative Care Network, LLC               MD
# 8      A17182        AAMC Collaborative Care Network, LLC               MD
# 9      A24077                           Abacus Health LLC               AZ
# 10     A24077                           Abacus Health LLC               AZ
# ...

# %%
df.drop_duplicates(subset=None, inplace=True)

# %%
#After without dupes
df
# Out:
#       ACO_Num                                           ACO_Name  \
# 0      A92107                                  Central Maine ACO
# 1      A38665                                              CCACO
# 2      A06665                                     JFK Health ACO
# 3      A17182               AAMC Collaborative Care Network, LLC
# 9      A24077                                  Abacus Health LLC
# 11     A66885                          Access Care Oklahoma, LLC
# 48     A19490                                           AccoCare
# 49     A59819                            ACO of East Hawaii, LLC
# 52     A25380          Accountable Care Alliance of Ventura, LLC
# 117    A70756  Accountable Care Coalition of Coastal Georgia,...
# 119    A86799        Accountable Care Coalition of Georgia, LLC.
# 120    A28160                                               ACMG
# 143    A08181    Accountable Care Coalition of Mississippi, LLC.
# ...

# %%
df.to_csv('/Users/davidlloyd/Documents/Networks/MSSPout.csv')
